# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open(r"C:\Users\Radhika K J\Downloads\frame3.jpg")

# %%
plt.imshow(image)
plt.title('Cheers to 26')
plt.axis('off')
plt.figure(figsize=(8,6))
plt.show()
